# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook reviews all the topics contained in the Course.
# **Objetives:**
# - Popular languages for Data Science
# - Common Libraries used by Data Science
# - Development Environments
# - Exercises with Python

# %% [markdown]
# ### This notebooks contains the Data Science tools viewed in the module "Tools For Data Science" summarized

# %% [markdown]
# Some of the popular language that are used by Data Scientist in the industry are the following
# 1. Python
# 2. R
# 3. Java
# 4. C++
# 5. SQL
# 6. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Sci-kit Learn
# 2. Pandas
# 3. Numpy
# 4. Seaborn
# 5. MatPlotLib

# %% [markdown]
# |Data Science Tools|
# | --- |
# |Jupyter|
# |JupyterLab|
# |RStudio|

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
3+14
# Out:
# 17

# %%
4*3
# Out:
# 12

# %%
3+3
# Out:
# 6

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor

# %% [markdown]
# Daniel A. Saldaña
